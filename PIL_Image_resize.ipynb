# %% [markdown]
# <a href="https://colab.research.google.com/github/taimur1871/simple-scripts/blob/master/PIL_Image_resize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt

# %%
test = Image.open('4.jpg')
test = test.rotate(-90)
width, height = test.size

# %%
#t = test.resize((int(width/8),int(height/8)))
t = test.resize((200,200))
t
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F9BEE2DCCF8>

# %%
t.size
# Out:
# (252, 189)

# %%
file_np = np.asanyarray(t)
file_np.shape
# Out:
# (189, 252, 3)
